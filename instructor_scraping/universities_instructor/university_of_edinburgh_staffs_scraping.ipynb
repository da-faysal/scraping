# %%
# Import required modules
import pandas as pd
from datetime import datetime

# %%
# We would use use pandas read html method to scrape the table info
# This returns a list of dataframes
listOfDfs = pd.read_html("https://www.ed.ac.uk/education/about-us/people/academic-staff-a-z")

# %%
# Since the length of the list is 1, so get the dataframe out of the table by
df = pd.concat(listOfDfs) # or, listOfDf[0]

# Check what we have
df.head(10)
# Out:
#   Name (sorted in ascending order)  \
# 0                  Dr Serdar Abaci
# 1                     Luke Addison
# 2                 Dr Ramsey Affifi
# 3                   Dr Farah Akbar
# 4                   Dr Fatih Aktas
# 5                Ramone Al Bishawi
# 6             Dr Maryam Almohammad
# 7        Professor Richard Andrews
# 8               Lorraine Archibald
# 9                  Dr Graham Baker
#
#                                                 Role  \
# 0            Lecturer in Data and Digital Literacies
# 1              Teaching Fellow in Childhood Practice
# 2  Lecturer, Science (Biology) & Environmental Ph...
# 3  Deputy Head of Institute for Language Educatio...
# 4                      Teaching Fellow MSc Education
# 5                                 Research Assistant
# 6              Teaching Fellow in Language Education
# 7  Head of Moray House School of Education and Sport
# 8                Teaching Fellow (Primary Education)
# 9           Lecturer in Physical Activity for Health
#
#                          Email         Phone number
# 0        serdar.abaci@ed.ac.uk                  NaN
# 1        luke.addison@ed.ac.uk                  NaN
# 2       ramsey.affifi@ed.ac.uk  +44 (0)131 651 6207
# 3         farah.akbar@ed.ac.uk  +44 (0)131 651 6445
# 4         fatih.aktas@ed.ac.uk                  NaN
# 5      ramone.bishawi@ed.ac.uk  +44 (0)131 651 7112
# 6   maryam.almohammad@ed.ac.uk  +44 (0)131 650 2796
# 7     richard.andrews@ed.ac.uk  +44 (0)131 651 6167
# 8  lorraine.archibald@ed.ac.uk  +44 (0)131 651 6418
# 9        graham.baker@ed.ac.uk  +44 (0)131 651 6034
